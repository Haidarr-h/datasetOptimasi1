# %% [markdown]
# ## Data Wrangling (Gathering, Accessing, and Cleaning)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import sys

# %%
distances_df = pd.read_csv('https://raw.githubusercontent.com/Haidarr-h/datasetOptimasi1/main/distance.csv')

# %%
distances_df.head()
# Out:
#    UserId     4    38    71    90    94   101   142   163   164  ...  8206  \
# 0       4     0  1280  1762  1406  1589  1312   941  1098  1020  ...  1377
# 1      38  1280     0   681   202   385   956  1639  1003  1520  ...  1817
# 2      71  1762   681     0   503   338  1512  2110  1524  2002  ...  2323
# 3      90  1406   202   503     0   208  1082  1765  1129  1646  ...  1943
# 4      94  1589   385   338   208     0  1264  1948  1311  1829  ...  2126
#
#    8232  8236  8255  8271  8300  8358  8360  8507  8545
# 0   321  1469  1398  1753  1762   846   777  1025  1017
# 1  1178   411  2029  1370   681  1603  1408  1515  1433
# 2  1660   342  2511  1926     0  2084  1890  1996  1915
# 3  1304   355  2155  1496   503  1728  1534  1640  1559
# 4  1487   226  2338  1679   338  1911  1717  1823  1742
#
# [5 rows x 237 columns]

# %% [markdown]
# ## Genetic Algorithm

# %% [markdown]
# #### Graph Visit Locations

# %%
locations_connections = {}
location_set = set()

def exist_connection(source, destination):
    return (True if (source, destination) in locations_connections else False)

def add_connection(source, destination, cost=0):
    if not exist_connection(source, destination):
        locations_connections[(source, destination)] = cost
        location_set.add(source)
        location_set.add(destination)

def get_cost_path(path):
    total_cost = 0
    for i in range(len(path)-1):
        if (path[i], path[i+1]) in locations_connections:
            total_cost = total_cost + locations_connections[(path[i], path[i+1])]
        else:
            print("Cost Antar Lokasi Tidak Ditemukan")
    return total_cost

def get_random_path(max_population):
    random_path = []
    location_list = list(location_set)
    first_location = random.choice(location_list)
    
    if first_location not in location_set:
        print("Lokasi Awal Pembentukan Path Tidak Ditemukan")
        sys.exit(1)
    
    location_list.remove(first_location)
    location_list.insert(0, first_location)

    for i in range(max_population):
        location_list_temp = location_list[1:]
        random.shuffle(location_list_temp)
        location_list_temp.insert(0, first_location)

        if location_list_temp not in random_path:
            random_path.append(location_list_temp)
    
    return random_path

def show_connections():
    print("Showing Locations Connections...")

    for location in locations_connections:
        print("Source :", location[0], "| Destination :", location[1], "| Cost", locations_connections[location])

# %% [markdown]
# #### Selection, Crossover, and Mutation Function

# %%
def select_parent(population, chromosome_amount):
    tournament_participants = random.choices(population, k=chromosome_amount)
    fitness_cost = [get_cost_path(chromosome) for chromosome in tournament_participants]
    best_chromosome_index = fitness_cost.index(min(fitness_cost))
    selected_parent = tournament_participants[best_chromosome_index]

    return selected_parent

def check_identical_parents(parent_1, parent_2):
    if len(parent_1)!=len(parent_2):
        print("Parents have different leng of chromosomes. Please kindly check it !")
        sys.exit(1)

    for i in range(len(parent_1)):
        if parent_1[i]!=parent_2[i]:
            return False

    return True

def crossover(parent_1, parent_2, point):
    child_chromosome = parent_1[0:point]

    for i in parent_2:
        if i not in child_chromosome:
            child_chromosome.append(i)

    return child_chromosome

def mutation(child, location_counts):
    index_1 = random.randint(0, location_counts-1)
    index_2 = random.randint(0, location_counts-1)

    while index_1 == index_2:
        index_2 = random.randint(0, location_counts-1)

    child[index_1], child[index_2] = child[index_2], child[index_1]

    return child

# %% [markdown]
# #### Genetic Algorithm Run

# %%
def run_genetic_algorithm(population_size, iteration, location_counts, tournament_selection_rate, mutation_rate, crossover_rate):
    generation_number = 0
    population = []
    population_cost = [0]*population_size
    
    # creating the first ever population
    population = get_random_path(population_size)
    # calculating the fitness of each chromosome
    for i in range(population_size):
        population_cost[i] = get_cost_path(population[i])

    # check the first population
    if not population:
        print("There are no population has been initialized yet, please kindly check the code!")
        sys.exit(1)
    
    # Main Loop
    for i in range(iteration):
        # Sorted the cost based on the index
        sorted_index_score = np.argsort(population_cost)
        new_population = []
        #new_population_cost = [0]*population_size

        # Pick the best two of the populations (elitism)
        new_population.append(population[sorted_index_score[0]])
        new_population.append(population[sorted_index_score[1]])

        for i in range((population_size-2)//2):
            # Crossovers
            if random.random() < crossover_rate:
                parent_1 = select_parent(population, tournament_selection_rate)
                parent_2 = select_parent(population, tournament_selection_rate)

                while(check_identical_parents(parent_1, parent_2) == True):
                    parent_2 = select_parent(population, tournament_selection_rate)

                point = random.randint(0, location_counts-1)
                child_1 = crossover(parent_1, parent_2, point)
                child_2 = crossover(parent_1, parent_2, point)
                
            # If crossover not happen
            else :
                child_1 = random.choices(population)[0]
                child_2 = random.choices(population)[0]

            # Mutation
            if random.random() < mutation_rate:
                child_1 = mutation(child_1, location_counts)
                child_2 = mutation(child_2, location_counts)


            new_population.append(child_1)
            new_population.append(child_2)

        population = new_population
        for i in range(population_size):
            population_cost[i] = get_cost_path(population[i])

        generation_number += 1

        best_chromosome = population[population_cost.index(min(population_cost))]

        if get_cost_path(best_chromosome) != min(population_cost):
            print("There is a difference between best Chromosome and Minimum Cost")
        
        if generation_number % 10 == 0:
            print('Generation :', generation_number, 'Best Chromosome Cost:', get_cost_path(best_chromosome))

    print('The Shortest Cost is', get_cost_path(best_chromosome))
    print('The shortest Route :', best_chromosome)
    print('Total Gen Number :', generation_number)

# %% [markdown]
# #### Main

# %%
def main():
    for i in distances_df.index:
      for x, j in enumerate(distances_df.columns[1:], start=1):
        j = int(j)
        # add source, destination, dan duration cost dari dataframe
        add_connection(distances_df.iloc[i,0], j, distances_df.iloc[i, x])
    
    population_size = 300
    iterations = 3000
    location_counts = len(location_set)
    tournament_selection_rate = 4
    mutation_rate = 0.1
    crossover_rate = 0.95

    #show_connections()

    run_genetic_algorithm(
        population_size, iterations, location_counts, tournament_selection_rate, mutation_rate, crossover_rate
    )

main()
# Out:
# 236
# Generation : 10 Best Chromosome Cost: 253280
# Generation : 20 Best Chromosome Cost: 240790
# Generation : 30 Best Chromosome Cost: 226712
# Generation : 40 Best Chromosome Cost: 212834
# Generation : 50 Best Chromosome Cost: 201913
# Generation : 60 Best Chromosome Cost: 194029
# Generation : 70 Best Chromosome Cost: 186543
# Generation : 80 Best Chromosome Cost: 181414
# Generation : 90 Best Chromosome Cost: 179496
# Generation : 100 Best Chromosome Cost: 176494
# Generation : 110 Best Chromosome Cost: 171221
# Generation : 120 Best Chromosome Cost: 167945
# Generation : 130 Best Chromosome Cost: 165926
# Generation : 140 Best Chromosome Cost: 164197
# Generation : 150 Best Chromosome Cost: 162288
# Generation : 160 Best Chromosome Cost: 157165
# Generation : 170 Best Chromosome Cost: 156026
# Generation : 180 Best Chromosome Cost: 152611
# Generation : 190 Best Chromosome Cost: 150226
# Generation : 200 Best Chromosome Cost: 148419
# Generation : 210 Best Chromosome Cost: 147295
# Generation : 220 Best Chromosome Cost: 145816
# Generation : 230 Best Chromosome Cost: 143584
# Generation : 240 Best Chromosome Cost: 141875
# Generation : 250 Best Chromosome Cost: 140034
# Generation : 260 Best Chromosome Cost: 138600
# Generation : 270 Best Chromosome Cost: 136501
# Generation : 280 Best Chromosome Cost: 135141
# Generation : 290 Best Chromosome Cost: 134074
# Generation : 300 Best Chromosome Cost: 133296
# Generation : 310 Best Chromosome Cost: 132946
# Generation : 320 Best Chromosome Cost: 131951
# Generation : 330 Best Chromosome Cost: 129342
# Generation : 340 Best Chromosome Cost: 128829
# Generation : 350 Best Chromosome Cost: 128401
# Generation : 360 Best Chromosome Cost: 126569
# Generation : 370 Best Chromosome Cost: 122865
# Generation : 380 Best Chromosome Cost: 120211
# Generation : 390 Best Chromosome Cost: 119438
# Generation : 400 Best Chromosome Cost: 119113
# Generation : 410 Best Chromosome Cost: 118412
# Generation : 420 Best Chromosome Cost: 116998
# Generation : 430 Best Chromosome Cost: 116070
# Generation : 440 Best Chromosome Cost: 115122
# Generation : 450 Best Chromosome Cost: 114670
# Generation : 460 Best Chromosome Cost: 113788
# Generation : 470 Best Chromosome Cost: 113356
# Generation : 480 Best Chromosome Cost: 112802
# Generation : 490 Best Chromosome Cost: 111949
# Generation : 500 Best Chromosome Cost: 111716
# Generation : 510 Best Chromosome Cost: 111511
# Generation : 520 Best Chromosome Cost: 110975
# Generation : 530 Best Chromosome Cost: 110429
# Generation : 540 Best Chromosome Cost: 109212
# Generation : 550 Best Chromosome Cost: 108900
# Generation : 560 Best Chromosome Cost: 107906
# Generation : 570 Best Chromosome Cost: 107839
# Generation : 580 Best Chromosome Cost: 106902
# Generation : 590 Best Chromosome Cost: 106744
# Generation : 600 Best Chromosome Cost: 105671
# Generation : 610 Best Chromosome Cost: 101591
# Generation : 620 Best Chromosome Cost: 101443
# Generation : 630 Best Chromosome Cost: 101086
# Generation : 640 Best Chromosome Cost: 100549
# Generation : 650 Best Chromosome Cost: 100236
# Generation : 660 Best Chromosome Cost: 98908
# Generation : 670 Best Chromosome Cost: 98730
# Generation : 680 Best Chromosome Cost: 98497
# Generation : 690 Best Chromosome Cost: 98197
# Generation : 700 Best Chromosome Cost: 97699
# Generation : 710 Best Chromosome Cost: 97693
# Generation : 720 Best Chromosome Cost: 97655
# Generation : 730 Best Chromosome Cost: 97526
# Generation : 740 Best Chromosome Cost: 97467
# Generation : 750 Best Chromosome Cost: 97279
# Generation : 760 Best Chromosome Cost: 96810
# Generation : 770 Best Chromosome Cost: 96059
# Generation : 780 Best Chromosome Cost: 95905
# Generation : 790 Best Chromosome Cost: 95609
# Generation : 800 Best Chromosome Cost: 95103
# Generation : 810 Best Chromosome Cost: 94836
# Generation : 820 Best Chromosome Cost: 94624
# Generation : 830 Best Chromosome Cost: 94516
# Generation : 840 Best Chromosome Cost: 94256
# Generation : 850 Best Chromosome Cost: 94141
# Generation : 860 Best Chromosome Cost: 94141
# Generation : 870 Best Chromosome Cost: 94084
# Generation : 880 Best Chromosome Cost: 94032
# Generation : 890 Best Chromosome Cost: 93809
# Generation : 900 Best Chromosome Cost: 93728
# Generation : 910 Best Chromosome Cost: 93405
# Generation : 920 Best Chromosome Cost: 93303
# Generation : 930 Best Chromosome Cost: 93303
# Generation : 940 Best Chromosome Cost: 93128
# Generation : 950 Best Chromosome Cost: 93099
# Generation : 960 Best Chromosome Cost: 93075
# Generation : 970 Best Chromosome Cost: 93075
# Generation : 980 Best Chromosome Cost: 92964
# Generation : 990 Best Chromosome Cost: 92604
# Generation : 1000 Best Chromosome Cost: 91726
# Generation : 1010 Best Chromosome Cost: 91701
# Generation : 1020 Best Chromosome Cost: 90221
# Generation : 1030 Best Chromosome Cost: 90142
# Generation : 1040 Best Chromosome Cost: 90142
# Generation : 1050 Best Chromosome Cost: 90142
# Generation : 1060 Best Chromosome Cost: 89854
# Generation : 1070 Best Chromosome Cost: 89484
# Generation : 1080 Best Chromosome Cost: 88964
# Generation : 1090 Best Chromosome Cost: 88953
# Generation : 1100 Best Chromosome Cost: 88953
# Generation : 1110 Best Chromosome Cost: 88943
# Generation : 1120 Best Chromosome Cost: 88852
# Generation : 1130 Best Chromosome Cost: 88136
# Generation : 1140 Best Chromosome Cost: 88055
# Generation : 1150 Best Chromosome Cost: 87977
# Generation : 1160 Best Chromosome Cost: 87673
# Generation : 1170 Best Chromosome Cost: 87673
# Generation : 1180 Best Chromosome Cost: 87673
# Generation : 1190 Best Chromosome Cost: 87630
# Generation : 1200 Best Chromosome Cost: 87557
# Generation : 1210 Best Chromosome Cost: 86129
# Generation : 1220 Best Chromosome Cost: 86017
# Generation : 1230 Best Chromosome Cost: 86011
# Generation : 1240 Best Chromosome Cost: 85898
# Generation : 1250 Best Chromosome Cost: 85868
# Generation : 1260 Best Chromosome Cost: 85796
# Generation : 1270 Best Chromosome Cost: 85228
# Generation : 1280 Best Chromosome Cost: 85228
# Generation : 1290 Best Chromosome Cost: 84984
# Generation : 1300 Best Chromosome Cost: 84983
# Generation : 1310 Best Chromosome Cost: 84982
# Generation : 1320 Best Chromosome Cost: 84981
# Generation : 1330 Best Chromosome Cost: 84944
# Generation : 1340 Best Chromosome Cost: 84904
# Generation : 1350 Best Chromosome Cost: 84844
# Generation : 1360 Best Chromosome Cost: 84598
# Generation : 1370 Best Chromosome Cost: 84529
# Generation : 1380 Best Chromosome Cost: 84525
# Generation : 1390 Best Chromosome Cost: 84524
# Generation : 1400 Best Chromosome Cost: 84382
# Generation : 1410 Best Chromosome Cost: 84382
# Generation : 1420 Best Chromosome Cost: 83918
# Generation : 1430 Best Chromosome Cost: 83616
# Generation : 1440 Best Chromosome Cost: 83462
# Generation : 1450 Best Chromosome Cost: 83462
# Generation : 1460 Best Chromosome Cost: 83386
# Generation : 1470 Best Chromosome Cost: 83315
# Generation : 1480 Best Chromosome Cost: 83315
# Generation : 1490 Best Chromosome Cost: 83315
# Generation : 1500 Best Chromosome Cost: 83283
# Generation : 1510 Best Chromosome Cost: 82728
# Generation : 1520 Best Chromosome Cost: 82728
# Generation : 1530 Best Chromosome Cost: 82560
# Generation : 1540 Best Chromosome Cost: 82415
# Generation : 1550 Best Chromosome Cost: 82411
# Generation : 1560 Best Chromosome Cost: 82410
# Generation : 1570 Best Chromosome Cost: 82366
# Generation : 1580 Best Chromosome Cost: 82003
# Generation : 1590 Best Chromosome Cost: 81854
# Generation : 1600 Best Chromosome Cost: 81707
# Generation : 1610 Best Chromosome Cost: 81707
# Generation : 1620 Best Chromosome Cost: 81707
# Generation : 1630 Best Chromosome Cost: 81707
# Generation : 1640 Best Chromosome Cost: 81707
# Generation : 1650 Best Chromosome Cost: 81707
# Generation : 1660 Best Chromosome Cost: 81605
# Generation : 1670 Best Chromosome Cost: 81605
# Generation : 1680 Best Chromosome Cost: 81605
# Generation : 1690 Best Chromosome Cost: 81424
# Generation : 1700 Best Chromosome Cost: 81293
# Generation : 1710 Best Chromosome Cost: 81146
# Generation : 1720 Best Chromosome Cost: 81094
# Generation : 1730 Best Chromosome Cost: 81094
# Generation : 1740 Best Chromosome Cost: 80999
# Generation : 1750 Best Chromosome Cost: 80999
# Generation : 1760 Best Chromosome Cost: 80999
# Generation : 1770 Best Chromosome Cost: 80996
# Generation : 1780 Best Chromosome Cost: 80597
# Generation : 1790 Best Chromosome Cost: 80579
# Generation : 1800 Best Chromosome Cost: 80547
# Generation : 1810 Best Chromosome Cost: 80441
# Generation : 1820 Best Chromosome Cost: 80430
# Generation : 1830 Best Chromosome Cost: 80429
# Generation : 1840 Best Chromosome Cost: 80429
# Generation : 1850 Best Chromosome Cost: 80429
# Generation : 1860 Best Chromosome Cost: 80429
# Generation : 1870 Best Chromosome Cost: 80385
# Generation : 1880 Best Chromosome Cost: 79981
# Generation : 1890 Best Chromosome Cost: 79926
# Generation : 1900 Best Chromosome Cost: 79926
# Generation : 1910 Best Chromosome Cost: 79513
# Generation : 1920 Best Chromosome Cost: 79425
# Generation : 1930 Best Chromosome Cost: 79425
# Generation : 1940 Best Chromosome Cost: 79425
# Generation : 1950 Best Chromosome Cost: 79312
# Generation : 1960 Best Chromosome Cost: 79294
# Generation : 1970 Best Chromosome Cost: 79294
# Generation : 1980 Best Chromosome Cost: 79294
# Generation : 1990 Best Chromosome Cost: 79233
# Generation : 2000 Best Chromosome Cost: 79233
# Generation : 2010 Best Chromosome Cost: 79224
# Generation : 2020 Best Chromosome Cost: 79224
# Generation : 2030 Best Chromosome Cost: 79224
# Generation : 2040 Best Chromosome Cost: 79224
# Generation : 2050 Best Chromosome Cost: 79224
# Generation : 2060 Best Chromosome Cost: 79218
# Generation : 2070 Best Chromosome Cost: 79192
# Generation : 2080 Best Chromosome Cost: 79062
# Generation : 2090 Best Chromosome Cost: 78748
# Generation : 2100 Best Chromosome Cost: 78714
# Generation : 2110 Best Chromosome Cost: 78680
# Generation : 2120 Best Chromosome Cost: 78559
# Generation : 2130 Best Chromosome Cost: 78558
# Generation : 2140 Best Chromosome Cost: 78493
# Generation : 2150 Best Chromosome Cost: 78493
# Generation : 2160 Best Chromosome Cost: 78489
# Generation : 2170 Best Chromosome Cost: 78304
# Generation : 2180 Best Chromosome Cost: 78295
# Generation : 2190 Best Chromosome Cost: 78295
# Generation : 2200 Best Chromosome Cost: 78295
# Generation : 2210 Best Chromosome Cost: 78198
# Generation : 2220 Best Chromosome Cost: 78192
# Generation : 2230 Best Chromosome Cost: 78192
# Generation : 2240 Best Chromosome Cost: 78192
# Generation : 2250 Best Chromosome Cost: 78192
# Generation : 2260 Best Chromosome Cost: 78192
# Generation : 2270 Best Chromosome Cost: 78153
# Generation : 2280 Best Chromosome Cost: 78153
# Generation : 2290 Best Chromosome Cost: 78153
# Generation : 2300 Best Chromosome Cost: 78153
# Generation : 2310 Best Chromosome Cost: 78048
# Generation : 2320 Best Chromosome Cost: 78048
# Generation : 2330 Best Chromosome Cost: 77859
# Generation : 2340 Best Chromosome Cost: 77681
# Generation : 2350 Best Chromosome Cost: 76948
# Generation : 2360 Best Chromosome Cost: 76948
# Generation : 2370 Best Chromosome Cost: 76948
# Generation : 2380 Best Chromosome Cost: 76887
# Generation : 2390 Best Chromosome Cost: 76887
# Generation : 2400 Best Chromosome Cost: 76887
# Generation : 2410 Best Chromosome Cost: 76887
# Generation : 2420 Best Chromosome Cost: 76887
# Generation : 2430 Best Chromosome Cost: 76887
# Generation : 2440 Best Chromosome Cost: 76752
# Generation : 2450 Best Chromosome Cost: 76751
# Generation : 2460 Best Chromosome Cost: 76751
# Generation : 2470 Best Chromosome Cost: 76618
# Generation : 2480 Best Chromosome Cost: 76595
# Generation : 2490 Best Chromosome Cost: 76525
# Generation : 2500 Best Chromosome Cost: 76496
# Generation : 2510 Best Chromosome Cost: 76423
# Generation : 2520 Best Chromosome Cost: 76419
# Generation : 2530 Best Chromosome Cost: 76418
# Generation : 2540 Best Chromosome Cost: 76285
# Generation : 2550 Best Chromosome Cost: 76024
# Generation : 2560 Best Chromosome Cost: 76023
# Generation : 2570 Best Chromosome Cost: 75974
# Generation : 2580 Best Chromosome Cost: 75973
# Generation : 2590 Best Chromosome Cost: 75973
# Generation : 2600 Best Chromosome Cost: 75973
# Generation : 2610 Best Chromosome Cost: 75477
# Generation : 2620 Best Chromosome Cost: 75403
# Generation : 2630 Best Chromosome Cost: 75379
# Generation : 2640 Best Chromosome Cost: 75325
# Generation : 2650 Best Chromosome Cost: 75325
# Generation : 2660 Best Chromosome Cost: 74093
# Generation : 2670 Best Chromosome Cost: 74093
# Generation : 2680 Best Chromosome Cost: 74093
# Generation : 2690 Best Chromosome Cost: 73881
# Generation : 2700 Best Chromosome Cost: 73789
# Generation : 2710 Best Chromosome Cost: 73789
# Generation : 2720 Best Chromosome Cost: 73786
# Generation : 2730 Best Chromosome Cost: 73786
# Generation : 2740 Best Chromosome Cost: 73786
# Generation : 2750 Best Chromosome Cost: 73786
# Generation : 2760 Best Chromosome Cost: 73786
# Generation : 2770 Best Chromosome Cost: 73786
# Generation : 2780 Best Chromosome Cost: 73786
# Generation : 2790 Best Chromosome Cost: 73786
# Generation : 2800 Best Chromosome Cost: 73786
# Generation : 2810 Best Chromosome Cost: 73786
# Generation : 2820 Best Chromosome Cost: 73705
# Generation : 2830 Best Chromosome Cost: 73705
# Generation : 2840 Best Chromosome Cost: 73705
# Generation : 2850 Best Chromosome Cost: 73705
# Generation : 2860 Best Chromosome Cost: 73678
# Generation : 2870 Best Chromosome Cost: 73675
# Generation : 2880 Best Chromosome Cost: 73675
# Generation : 2890 Best Chromosome Cost: 73675
# Generation : 2900 Best Chromosome Cost: 73675
# Generation : 2910 Best Chromosome Cost: 73675
# Generation : 2920 Best Chromosome Cost: 73675
# Generation : 2930 Best Chromosome Cost: 73675
# Generation : 2940 Best Chromosome Cost: 73675
# Generation : 2950 Best Chromosome Cost: 73675
# Generation : 2960 Best Chromosome Cost: 73670
# Generation : 2970 Best Chromosome Cost: 73670
# Generation : 2980 Best Chromosome Cost: 73670
# Generation : 2990 Best Chromosome Cost: 73670
# Generation : 3000 Best Chromosome Cost: 73670
# The Shortest Cost is 73670
# The shortest Route : [5520, 664, 6796, 3359, 3862, 3801, 5261, 7270, 1767, 5474, 5706, 4655, 2176, 4603, 280, 1039, 8195, 336, 1926, 8179, 940, 8300, 4120, 90, 6451, 7567, 6846, 4322, 1407, 760, 3214, 7108, 1540, 5143, 1508, 5308, 1388, 3218, 101, 7512, 8271, 5655, 8177, 1973, 216, 2442, 4531, 2670, 7020, 7158, 5757, 1538, 1310, 1467, 1808, 1758, 5227, 3241, 3242, 4150, 6983, 2717, 2384, 4936, 3348, 5950, 6078, 7120, 1136, 3268, 6898, 6540, 1824, 5630, 5023, 8232, 3643, 4357, 3647, 3451, 7649, 4484, 7071, 6432, 5501, 5492, 2354, 3839, 7629, 3897, 7289, 1363, 5669, 6857, 1560, 1231, 8236, 7578, 1412, 2056, 4794, 653, 6891, 1631, 4100, 213, 94, 6993, 1788, 1907, 7320, 8358, 1071, 4669, 5895, 2619, 2698, 196, 3764, 2713, 3509, 4966, 3606, 7591, 5939, 7346, 4300, 3040, 1430, 3052, 1468, 4027, 6007, 985, 3648, 164, 5415, 5068, 142, 6454, 5264, 3518, 5958, 7396, 4859, 1989, 1138, 683, 464, 6967, 1626, 1848, 7573, 554, 3507, 8201, 6658, 6322, 8360, 1076, 2265, 7549, 7372, 4, 7068, 2451, 3408, 2192, 3828, 2002, 4570, 71, 6331, 7304, 7514, 4661, 1175, 6856, 6819, 4356, 520, 3118, 671, 5223, 163, 1304, 5259, 6972, 7028, 918, 864, 6405, 4398, 6048, 7352, 3120, 5639, 8206, 4839, 2736, 7599, 5545, 2680, 6966, 8172, 2048, 7328, 38, 2139, 5665, 4525, 8545, 8507, 3436, 5500, 3234, 4703, 1073, 1116, 304, 2091, 1327, 1918, 3091, 5408, 201, 466, 3431, 4535, 1337, 4758, 3719, 8255, 568, 8143, 607]
# Total Gen Number : 3000

# %%
x = [6857, 5259, 280, 2698, 196, 3509, 1508, 7514, 1175, 6819, 6856, 4661, 2442, 4531, 7020, 6451, 3234, 304, 1116, 2670, 101, 5545, 7599, 6972, 5023, 4669, 3648, 164, 8507, 213, 7578, 3052, 1560, 7028, 5264, 6966, 2680, 142, 5068, 985, 8545, 38, 7573, 554, 8201, 163, 5223, 7289, 1363, 5143, 3839, 4655, 5706, 5474, 5639, 8206, 3214, 6405, 4398, 7352, 6048, 3120, 4484, 216, 520, 4356, 1407, 760, 2736, 4839, 1076, 4027, 4120, 1337, 4794, 4535, 2056, 94, 4525, 5665, 1848, 1626, 4703, 1073, 5757, 7158, 7304, 8271, 7512, 5655, 8255, 568, 3241, 5227, 5630, 1138, 1989, 7068, 2451, 8232, 3643, 6540, 1824, 4859, 683, 4603, 3408, 464, 6898, 7396, 1304, 7649, 2091, 3647, 1788, 1907, 7320, 3436, 5500, 7328, 5958, 3518, 6983, 2717, 4150, 3801, 2619, 8172, 8358, 653, 8300, 6331, 336, 8360, 6322, 2713, 3764, 7270, 1767, 4936, 2354, 7629, 5669, 1758, 466, 3091, 1918, 201, 1467, 5408, 1808, 6796, 6007, 1468, 7567, 3118, 4322, 1973, 8177, 1388, 3218, 5308, 671, 3897, 6993, 1540, 3348, 5950, 6078, 7108, 6658, 3359, 3862, 1327, 1926, 940, 1631, 8195, 4100, 90, 6846, 5261, 7346, 1430, 3040, 4300, 4357, 3451, 2139, 3507, 6967, 1231, 918, 864, 1039, 8236, 2192, 4966, 3606, 3719, 1310, 1538, 664, 5520, 2265, 2176, 4758, 3242, 5939, 7591, 7120, 2384, 5492, 7549, 7372, 4, 8179, 71, 4570, 2002, 3828, 7071, 6432, 5501, 1136, 3268, 6454, 6891, 8143, 607, 2048, 1071, 5895, 5415, 1412, 3431]
get_cost_path(x)
#print(all(element in x for element in location_set))
#print(all(element in location_set for element in x))
# Out:
# 91286
